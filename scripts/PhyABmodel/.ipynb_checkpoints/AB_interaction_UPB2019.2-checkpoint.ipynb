# %%
# %pylab inline
import tellurium as te
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
levels={}

# %%
#figure(dpi=600)
model = te.loadAntimonyModel('phyAB_interaction')
#model.setValue('FR_levels',0)
model.setValue('mutb',0)
model.setValue('R',0)
model.setValue('FR',0)
model.setValue('R_levels',1)
model.setValue('FR_levels',0.0001)

res = model.simulate(0,24*10,1000)
levels['WT_R']=(res['[Am]']/max(res['[Am]']))[-1]

#plot(res['time']-60,res['[Am]']/max(res['[Am]'])*100,'k' ,label='WT')
#plot(res['time']-60,res['[A]']/max(res['[A]'])*100,'k--' ,label='WT')

model = te.loadAntimonyModel('phyAB_interaction')
#model.setValue('FR_levels',0)
model.setValue('mutb',1)
model.setValue('R',0)
model.setValue('FR',0)
model.setValue('R_levels',1)
model.setValue('FR_levels',0.0001)
res = model.simulate(0,24*10,1000)

levels['phyb_R']=(res['[Am]']/max(res['[Am]']))[-1]

#plot(res['time']-60,res['[Am]']/max(res['[Am]'])*100,'r' ,label='phyB mut')
#plot(res['time']-60,res['[A]']/max(res['[A]'])*100,'r--' ,label='phyB mut')


#axvspan(0,40, color='gray', alpha=0.5)
#xlim(0,100)
#ylim(0,100)
#yticks(fontsize=20)
#xticks(fontsize=20)
#xlim(150,200)
#for i in range(0,10):
#    axvspan(12+(24*i),24+24*i, color='gray', alpha=0.5)
#legend(loc='lower right', fontsize=18)
#savefig('PhyA_transcript_wt_phymut_red.svg', format='svg', dpi=600, transparent=True)

# %%
#figure(dpi=600)
model = te.loadAntimonyModel('phyAB_interaction')
#model.setValue('FR_levels',0)
model.setValue('mutb',0)
model.setValue('R',0)
model.setValue('FR',0)
model.setValue('R_levels',0.0001)
model.setValue('FR_levels',1)

res = model.simulate(0,24*10,1000)

levels['WT_fr']=(res['[Am]']/max(res['[Am]']))[-1]

#plot(res['time']-60,res['[Am]']/max(res['[Am]'])*100,'k' ,label='WT')

model = te.loadAntimonyModel('phyAB_interaction')
#model.setValue('FR_levels',0)
model.setValue('mutb',1)
model.setValue('R',0)
model.setValue('FR',0)
model.setValue('R_levels',0.0001)
model.setValue('FR_levels',1)
res = model.simulate(0,24*10,1000)
#plot(res['time']-60,res['[Am]']/max(res['[Am]'])*100,'r' ,label='phyA mut')
#plot(res['time']-60,res['[A]']/max(res['[A]'])*100,'r--' ,label='phyA protein mut')
levels['phyb_fr']=(res['[Am]']/max(res['[Am]']))[-1]


#axvspan(0,40, color='gray', alpha=0.5)
#xlim(0,100)
#ylim(0,100)
#yticks(fontsize=20)
#xticks(fontsize=20)
#xlim(150,200)
#for i in range(0,10):
#    axvspan(12+(24*i),24+24*i, color='gray', alpha=0.5)
#legend(loc='upper right', fontsize=18)
#title('PhyB mutant in Far-red')
#savefig('PhyA_transcript_wt_phymut.svg', format='svg', dpi=600, transparent=True)

# %%
#figure(dpi=600)
model = te.loadAntimonyModel('phyAB_interaction')
#model.setValue('FR_levels',0)
model.setValue('muta',0)
model.setValue('R_levels',1)
model.setValue('FR_levels',0.0001)

res = model.simulate(0,24*10,1000)
#plot(res['time']-60,res['[Am]']/max(res['[Am]'])*100,'k' ,label='WT')
levels['WT_R']=(res['[Am]']/max(res['[Am]']))[-1]

model = te.loadAntimonyModel('phyAB_interaction')
#model.setValue('FR_levels',0)
model.setValue('muta',1)
model.setValue('R_levels',1)
model.setValue('FR_levels',0.0001)

res = model.simulate(0,24*10,1000)
#plot(res['time']-60,res['[Am]']/max(res['[Am]'])*100,'r' ,label='phyA mut')
levels['phya_R']=(res['[Am]']/max(res['[Am]']))[-1]



#axvspan(0,40, color='gray', alpha=0.5)
#xlim(0,100)
#ylim(0,100)
#yticks(fontsize=20)
#xticks(fontsize=20)
#xlim(150,200)
#for i in range(0,10):
#    axvspan(12+(24*i),24+24*i, color='gray', alpha=0.5)
#legend(loc='upper right', fontsize=18)
#savefig('PhyA_transcript_wt_phymut.svg', format='svg', dpi=600, transparent=True)

# %%
#figure(dpi=600)
model = te.loadAntimonyModel('phyAB_interaction')
#model.setValue('FR_levels',0)
model.setValue('muta',0)
model.setValue('R_levels',0.0001)
model.setValue('FR_levels',1)

res = model.simulate(0,24*10,1000)
#plot(res['time']-60,res['[Am]']/max(res['[Am]'])*100,'k' ,label='WT')
levels['WT_fr']=(res['[Am]']/max(res['[Am]']))[-1]


model = te.loadAntimonyModel('phyAB_interaction')
#model.setValue('FR_levels',0)
model.setValue('muta',1)
model.setValue('R_levels',0.0001)
model.setValue('FR_levels',1)

res = model.simulate(0,24*10,1000)
#plot(res['time']-60,res['[Am]']/max(res['[Am]'])*100,'r' ,label='phyA mut')
levels['phya_fr']=(res['[Am]']/max(res['[Am]']))[-1]



#axvspan(0,40, color='gray', alpha=0.5)
#xlim(0,100)
#ylim(0,105)
#yticks(fontsize=20)
#xticks(fontsize=20)
#xlim(150,200)
#for i in range(0,10):
#    axvspan(12+(24*i),24+24*i, color='gray', alpha=0.5)
#legend(loc='upper right', fontsize=18)
#savefig('PhyA_transcript_wt_phymut.svg', format='svg', dpi=600, transparent=True)

# %%
phyA_data = pd.read_excel('PhyAmRNA_levels_steady_Canton1999.xlsx')
phyA_data
# Out:
#    RLD FR   RLD R   RLD W  phyA-101 FR  phyA-101 R  phyA-101 W  Ler FR  \
# 0  33.023  40.894  36.727      100.304      49.689      50.769  24.536
# 1  38.424  44.905  39.813      105.242      58.485      62.034  34.258
# 2   5.401   4.011   3.086        4.938       8.796      11.265   9.722
#
#     Ler R   Ler W  phyB-5 FR  phyB-5 R  phyB-5 W
# 0  43.054  33.641     29.628    90.583    57.405
# 1  46.140  35.801     39.196   101.385    59.874
# 2   3.086   2.160      9.568    10.802     2.469

# %%
levels
# Out:
# {'WT_R': 0.5207659524507269,
#  'WT_fr': 0.33065020603565537,
#  'phya_R': 0.5208337694041638,
#  'phya_fr': 0.9997383402752673,
#  'phyb_R': 0.9996650335074803,
#  'phyb_fr': 0.3306827577596296}

# %%
figure(dpi=600)
bar([1,],array([1,])*100, color='k')
bar([2,],phyA_data.iloc[0,0],yerr=phyA_data.iloc[2,0], color='#840101')
bar([3,],array([levels['WT_fr'],])*100, color='#840101', hatch="///")
bar([4,],phyA_data.iloc[0,1],yerr=phyA_data.iloc[2,1], color='red')
bar([5,],array([levels['WT_R'],])*100, color='red', hatch="///")

bar([8,],array([1,])*100, color='k')
bar([9,],phyA_data.iloc[0,3],yerr=phyA_data.iloc[2,3], color='#840101')
bar([10,],array([levels['phya_fr'],])*100, color='#840101', hatch="///")
bar([11,],phyA_data.iloc[0,4],yerr=phyA_data.iloc[2,3], color='red')
bar([12,],array([levels['phya_R'],])*100, color='red', hatch="///")


bar([15,],array([1,])*100, color='k')
bar([16,],phyA_data.iloc[0,9],yerr=phyA_data.iloc[2,9], color='#840101')
bar([17,],array([levels['phyb_fr'],])*100, color='#840101', hatch="///")
bar([18,],phyA_data.iloc[0,10],yerr=phyA_data.iloc[2,10], color='red')
bar([19,],array([levels['phyb_R'],])*100, color='red', hatch="///")

ylim(0,120)
xlim(0,20)
yticks(fontsize=22)
xticks([])
savefig('steady_state_lavels_phyA_different_light_conditions.png', format='png', dpi=600, transparent=True)

# %%
figure(dpi=600)

model = te.loadAntimonyModel('phyAB_interaction')
model.setValue('FR_levels',0)
model.setValue('muta',0)
model.setValue('R',0)
model.setValue('PF',16)
res = model.simulate(0,24*10,1000)
plot(res['time']-24*2,res['[Ar]']*10+res['[Afr]']*10,'k' ,label='PhyA longday')

model = te.loadAntimonyModel('phyAB_interaction')
model.setValue('FR_levels',0)
model.setValue('muta',0)
model.setValue('R',0)
model.setValue('PF',8)
res = model.simulate(0,24*10,1000)
plot(res['time']-24*2,res['[Ar]']*10+res['[Afr]']*10,'b' ,label='PhyA shortday')


#axvspan(0,40, color='gray', alpha=0.5)
xticks(range(0,24*10,8), fontsize=20)
yticks(fontsize=20)
xlim(0,48)
ylim(0,3)
#xlim(150,200)
for i in range(0,10):
    axvspan(16+(24*i),24+24*i, color='gray', alpha=0.5)
    
for i in range(0,10):
    axvspan(8+(24*i),24+24*i, color='gray', alpha=0.5)
legend(loc='upper right', fontsize=18)
savefig('PhyA_protein_SD_vs_LD.png', format='png', dpi=600, transparent=True)

# %%
figure(dpi=600)

model = te.loadAntimonyModel('phyAB_interaction')
model.setValue('FR_levels',0)

model.setValue('PF',16)
res = model.simulate(0,24*10,1000)
a_max = max(res['[Afr]'][-500:])
plot(res['time']-24*2,res['[Afr]']*10+res['[Ar]']*10,'k' ,label='PhyA W')
plot(res['time']-24*2,res['[Bfr]'],'b--' ,label='Bfr W')

model = te.loadAntimonyModel('phyAB_interaction')
model.setValue('FR_levels',10)

model.setValue('PF',16)
res = model.simulate(0,24*10,1000)
plot(res['time']-24*2,res['[Afr]']*10+res['[Ar]']*10,'r' ,label='PhyA W + FR')
plot(res['time']-24*2,res['[Bfr]'],'b-' ,label='Bfr W + FR')


#axvspan(0,40, color='gray', alpha=0.5)
xticks([0,16,24,24+16,48],fontsize=20)
xlim(0,48)
yticks(fontsize=20)
#ylim(0,0.5)
#xlim(150,200)
for i in range(0,10):
    axvspan(16+(24*i),24+24*i, color='gray', alpha=0.5)
ylim(0,3)    
#for i in range(0,10):
#    axvspan(8+(24*i),24+24*i, color='gray', alpha=0.5)
legend(loc='upper right', fontsize=16)
savefig('PhyA_protein_W_vs_W+FR.png', format='png', dpi=600, transparent=True)
